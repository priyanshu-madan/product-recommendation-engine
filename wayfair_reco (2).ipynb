# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/priyanshumadan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv("wayfair_uniq.csv")
df_new=df.iloc[:,[3,4,5,7,9,11,13,15,17,18,19]]

# %%
df_new['index'] = df_new.index

# %%
df_new.shape
# Out:
# (17209, 12)

# %%
df_new.head()
# Out:
#                                 product_name  \
# 0               Ariana 63" Column Floor Lamp
# 1          Dale 63.75" Arched/Arc Floor Lamp
# 2  Carlisle Douthit 70" Swing Arm Floor Lamp
# 3                Morrill 82" Tree Floor Lamp
# 4   Shipton Crystal and Metal 61" Floor Lamp
#
#                                    product_name_link             manufacturer  \
# 0  https://www.wayfair.com/lighting/pdp/zipcode-d...        by Zipcode Design
# 1  https://www.wayfair.com/v/wayup/sponsored_skus...        by Langley Street
# 2  https://www.wayfair.com/lighting/pdp/williston...       by Williston Forge
# 3  https://www.wayfair.com/lighting/pdp/brayden-s...        by Brayden Studio
# 4  https://www.wayfair.com/lighting/pdp/willa-arl...  by Willa Arlo Interiors
#
#                    price original_price  review_count  \
# 0    from $38.02; $38.02        $69.99         3878.0
# 1         $73.99; $73.99        $99.99         1382.0
# 2  from $104.99; $104.99       $399.99         1084.0
# 3       $143.99; $143.99       $230.00         3476.0
# 4         $62.99; $62.99       $170.04         2099.0
#
#                                   review_data        shipping_time  \
# 0  Rated 4.5 out of 5 stars.3878 total votes.                  NaN
# 1  Rated 4.5 out of 5 stars.1382 total votes.  FREE 2-Day Shipping
# 2  Rated 4.5 out of 5 stars.1084 total votes.  FREE 2-Day Shipping
# 3  Rated 4.5 out of 5 stars.3476 total votes.  FREE 2-Day Shipping
# 4  Rated 4.5 out of 5 stars.2099 total votes.  FREE 2-Day Shipping
#
#                                      product_descrip  \
# 0  Short on space? Make the most of your square f...
# 1  With a slender silhouette, this floor lamp bri...
# 2  Part decor and part luminary, we love floor la...
# 3  When your ensemble is in need of a little illu...
# 4  Equally alluring sitting sofa-side for a littl...
#
#                 product_data1                         product_data2  index
# 0  Switch Type: On/Off switch                                   NaN      0
# 1    Switch Type: Foot Switch  Maximum Wattage (per Bulb): 100 Watt      1
# 2  Switch Type: Rotary socket  Maximum Wattage (per Bulb): 100 Watt      2
# 3          Switch Type: 4-Way   Maximum Wattage (per Bulb): 26 Watt      3
# 4  Switch Type: On/Off switch   Maximum Wattage (per Bulb): 60 Watt      4

# %%
def get_title_from_index(index):
    return df_new[df_new.index == index]["product_name"].values[0]

def get_home(index):
    return df_new[df_new.index == index]["product_name_link"].values[0]

def get_index_from_title(title):
    return df_new[df_new.product_name == title]["index"].values[0]

# %%
print (df_new.columns)
# Out:
# Index(['product_name', 'product_name_link', 'manufacturer', 'price',
#        'original_price', 'review_count', 'review_data', 'shipping_time',
#        'product_descrip', 'product_data1', 'product_data2', 'index'],
#       dtype='object')

# %%
df_new['original_price'] = df_new.original_price.str.replace('$', '')
df_new['original_price'] = df_new.original_price.str.replace(',', '').astype(float)

# %%
new_price = df_new["price"].str.split(";\s\$", n = 1, expand = True)
df_new["new_price"] = new_price[1]
df_new.drop(columns =["price"], inplace = True)

# %%
price_range = df_new[df_new["new_price"].str.contains("-",regex=True)]

# %%
price_range['new_price'] = (price_range['new_price'].str.split("\s-", n = 1, expand = True))[0]

# %%
df_new.loc[price_range.index] = price_range

# %%
df_new['new_price'] = df_new.new_price.str.replace(',', '').astype(float)

# %%
bins = [0,500,1000,1500,2000,2500,3000,3500,4000,4500,35000]
labels = ["<$500","$500-$1000","$1000-$1500","$1500-$2000","$2000-$2500","$2500-$3000","$3000-$3500","$3500-$4000","$4000-$4500",">$4500"]
df_new['price_bracket'] = pd.cut(df_new['new_price'], bins, labels=labels)

# %%
features = ["product_data1","product_data2","product_descrip","manufacturer"]

# %%
for feature in features:
    df_new[feature] = df_new[feature].fillna('')

# %%
def combine_features(row):
    try:
        return row['product_data1'] +" "+row['product_data2']+" "+row["product_descrip"]+" "+row["price_bracket"]+" "+row["manufacturer"]
    except:
        print("Error:", row)

# %%
df_new["combined_features"] = df_new.apply(combine_features,axis=1)

# %%
df_new.head()
# Out:
#                                 product_name  \
# 0               Ariana 63" Column Floor Lamp
# 1          Dale 63.75" Arched/Arc Floor Lamp
# 2  Carlisle Douthit 70" Swing Arm Floor Lamp
# 3                Morrill 82" Tree Floor Lamp
# 4   Shipton Crystal and Metal 61" Floor Lamp
#
#                                    product_name_link             manufacturer  \
# 0  https://www.wayfair.com/lighting/pdp/zipcode-d...        by Zipcode Design
# 1  https://www.wayfair.com/v/wayup/sponsored_skus...        by Langley Street
# 2  https://www.wayfair.com/lighting/pdp/williston...       by Williston Forge
# 3  https://www.wayfair.com/lighting/pdp/brayden-s...        by Brayden Studio
# 4  https://www.wayfair.com/lighting/pdp/willa-arl...  by Willa Arlo Interiors
#
#    original_price  review_count                                 review_data  \
# 0           69.99        3878.0  Rated 4.5 out of 5 stars.3878 total votes.
# 1           99.99        1382.0  Rated 4.5 out of 5 stars.1382 total votes.
# 2          399.99        1084.0  Rated 4.5 out of 5 stars.1084 total votes.
# 3          230.00        3476.0  Rated 4.5 out of 5 stars.3476 total votes.
# 4          170.04        2099.0  Rated 4.5 out of 5 stars.2099 total votes.
#
#          shipping_time                                    product_descrip  \
# 0                  NaN  Short on space? Make the most of your square f...
# 1  FREE 2-Day Shipping  With a slender silhouette, this floor lamp bri...
# 2  FREE 2-Day Shipping  Part decor and part luminary, we love floor la...
# 3  FREE 2-Day Shipping  When your ensemble is in need of a little illu...
# 4  FREE 2-Day Shipping  Equally alluring sitting sofa-side for a littl...
#
#                 product_data1                         product_data2  index  \
# 0  Switch Type: On/Off switch                                            0
# 1    Switch Type: Foot Switch  Maximum Wattage (per Bulb): 100 Watt      1
# 2  Switch Type: Rotary socket  Maximum Wattage (per Bulb): 100 Watt      2
# 3          Switch Type: 4-Way   Maximum Wattage (per Bulb): 26 Watt      3
# 4  Switch Type: On/Off switch   Maximum Wattage (per Bulb): 60 Watt      4
#
#    new_price price_bracket                                  combined_features
# 0      38.02         <$500  Switch Type: On/Off switch  Short on space? Ma...
# 1      73.99         <$500  Switch Type: Foot Switch Maximum Wattage (per ...
# 2     104.99         <$500  Switch Type: Rotary socket Maximum Wattage (pe...
# 3     143.99         <$500  Switch Type: 4-Way Maximum Wattage (per Bulb):...
# 4      62.99         <$500  Switch Type: On/Off switch Maximum Wattage (pe...

# %%
stop_words = stopwords.words('english')

# %%
df_new['combined_features'] = df_new['combined_features'].str.lower().str.split()

# %%
df_new.head()
# Out:
#                                 product_name  \
# 0               Ariana 63" Column Floor Lamp
# 1          Dale 63.75" Arched/Arc Floor Lamp
# 2  Carlisle Douthit 70" Swing Arm Floor Lamp
# 3                Morrill 82" Tree Floor Lamp
# 4   Shipton Crystal and Metal 61" Floor Lamp
#
#                                    product_name_link             manufacturer  \
# 0  https://www.wayfair.com/lighting/pdp/zipcode-d...        by Zipcode Design
# 1  https://www.wayfair.com/v/wayup/sponsored_skus...        by Langley Street
# 2  https://www.wayfair.com/lighting/pdp/williston...       by Williston Forge
# 3  https://www.wayfair.com/lighting/pdp/brayden-s...        by Brayden Studio
# 4  https://www.wayfair.com/lighting/pdp/willa-arl...  by Willa Arlo Interiors
#
#    original_price  review_count                                 review_data  \
# 0           69.99        3878.0  Rated 4.5 out of 5 stars.3878 total votes.
# 1           99.99        1382.0  Rated 4.5 out of 5 stars.1382 total votes.
# 2          399.99        1084.0  Rated 4.5 out of 5 stars.1084 total votes.
# 3          230.00        3476.0  Rated 4.5 out of 5 stars.3476 total votes.
# 4          170.04        2099.0  Rated 4.5 out of 5 stars.2099 total votes.
#
#          shipping_time                                    product_descrip  \
# 0                  NaN  Short on space? Make the most of your square f...
# 1  FREE 2-Day Shipping  With a slender silhouette, this floor lamp bri...
# 2  FREE 2-Day Shipping  Part decor and part luminary, we love floor la...
# 3  FREE 2-Day Shipping  When your ensemble is in need of a little illu...
# 4  FREE 2-Day Shipping  Equally alluring sitting sofa-side for a littl...
#
#                 product_data1                         product_data2  index  \
# 0  Switch Type: On/Off switch                                            0
# 1    Switch Type: Foot Switch  Maximum Wattage (per Bulb): 100 Watt      1
# 2  Switch Type: Rotary socket  Maximum Wattage (per Bulb): 100 Watt      2
# 3          Switch Type: 4-Way   Maximum Wattage (per Bulb): 26 Watt      3
# 4  Switch Type: On/Off switch   Maximum Wattage (per Bulb): 60 Watt      4
#
#    new_price price_bracket                                  combined_features
# 0      38.02         <$500  [switch, type:, on/off, switch, short, on, spa...
# 1      73.99         <$500  [switch, type:, foot, switch, maximum, wattage...
# 2     104.99         <$500  [switch, type:, rotary, socket, maximum, watta...
# 3     143.99         <$500  [switch, type:, 4-way, maximum, wattage, (per,...
# 4      62.99         <$500  [switch, type:, on/off, switch, maximum, watta...

# %%
df_new["features"]=df_new["combined_features"].apply(lambda x: [word for word in x if word not in stop_words])

# %%
df_new.head()
# Out:
#                                 product_name  \
# 0               Ariana 63" Column Floor Lamp
# 1          Dale 63.75" Arched/Arc Floor Lamp
# 2  Carlisle Douthit 70" Swing Arm Floor Lamp
# 3                Morrill 82" Tree Floor Lamp
# 4   Shipton Crystal and Metal 61" Floor Lamp
#
#                                    product_name_link             manufacturer  \
# 0  https://www.wayfair.com/lighting/pdp/zipcode-d...        by Zipcode Design
# 1  https://www.wayfair.com/v/wayup/sponsored_skus...        by Langley Street
# 2  https://www.wayfair.com/lighting/pdp/williston...       by Williston Forge
# 3  https://www.wayfair.com/lighting/pdp/brayden-s...        by Brayden Studio
# 4  https://www.wayfair.com/lighting/pdp/willa-arl...  by Willa Arlo Interiors
#
#    original_price  review_count                                 review_data  \
# 0           69.99        3878.0  Rated 4.5 out of 5 stars.3878 total votes.
# 1           99.99        1382.0  Rated 4.5 out of 5 stars.1382 total votes.
# 2          399.99        1084.0  Rated 4.5 out of 5 stars.1084 total votes.
# 3          230.00        3476.0  Rated 4.5 out of 5 stars.3476 total votes.
# 4          170.04        2099.0  Rated 4.5 out of 5 stars.2099 total votes.
#
#          shipping_time                                    product_descrip  \
# 0                  NaN  Short on space? Make the most of your square f...
# 1  FREE 2-Day Shipping  With a slender silhouette, this floor lamp bri...
# 2  FREE 2-Day Shipping  Part decor and part luminary, we love floor la...
# 3  FREE 2-Day Shipping  When your ensemble is in need of a little illu...
# 4  FREE 2-Day Shipping  Equally alluring sitting sofa-side for a littl...
#
#                 product_data1                         product_data2  index  \
# 0  Switch Type: On/Off switch                                            0
# 1    Switch Type: Foot Switch  Maximum Wattage (per Bulb): 100 Watt      1
# 2  Switch Type: Rotary socket  Maximum Wattage (per Bulb): 100 Watt      2
# 3          Switch Type: 4-Way   Maximum Wattage (per Bulb): 26 Watt      3
# 4  Switch Type: On/Off switch   Maximum Wattage (per Bulb): 60 Watt      4
#
#    new_price price_bracket                                  combined_features  \
# 0      38.02         <$500  [switch, type:, on/off, switch, short, on, spa...
# 1      73.99         <$500  [switch, type:, foot, switch, maximum, wattage...
# 2     104.99         <$500  [switch, type:, rotary, socket, maximum, watta...
# 3     143.99         <$500  [switch, type:, 4-way, maximum, wattage, (per,...
# 4      62.99         <$500  [switch, type:, on/off, switch, maximum, watta...
#
#                                             features
# 0  [switch, type:, on/off, switch, short, space?,...
# 1  [switch, type:, foot, switch, maximum, wattage...
# 2  [switch, type:, rotary, socket, maximum, watta...
# 3  [switch, type:, 4-way, maximum, wattage, (per,...
# 4  [switch, type:, on/off, switch, maximum, watta...

# %%
df_new["features"]=df_new["features"].apply(lambda x: " ".join(x))

# %%
cv = CountVectorizer()

# %%
count_matrix = cv.fit_transform(df_new["features"])

# %%
count_matrix
# Out:
# <17209x13136 sparse matrix of type '<class 'numpy.int64'>'
# 	with 607000 stored elements in Compressed Sparse Row format>

# %%
cosine_sim = cosine_similarity(count_matrix)

# %%
product_user_likes = 'Bjorn Chesterfield Settee'

# %%
product_index = get_index_from_title(product_user_likes)

similar_products =  list(enumerate(cosine_sim[product_index]))

# %%
sorted_similar_products = sorted(similar_products,key=lambda x:x[1],reverse=True)

# %%
i=0
for element in sorted_similar_products:
        print (get_title_from_index(element[0]),get_home(element[0]))
        i=i+1
        if i>50:
            break
# Out:
# Bjorn Chesterfield Settee https://www.wayfair.com/furniture/pdp/andover-mills-bjorn-chesterfield-settee-w000619313.html
# Kaitlyn Settee https://www.wayfair.com/furniture/pdp/andover-mills-kaitlyn-settee-w000539497.html
# Thame Swoop Arm Settee Sofa & Chaise https://www.wayfair.com/furniture/pdp/brayden-studio-thame-swoop-arm-settee-sofa-chaise-bydt1178.html
# Forest River Tufted Loveseat https://www.wayfair.com/furniture/pdp/forest-river-tufted-loveseat-lfmf3375.html
# Omar Loveseat https://www.wayfair.com/furniture/pdp/charlton-home-omar-loveseat-cnta1632.html
# Jonas Loveseat https://www.wayfair.com/furniture/pdp/andover-mills-jonas-loveseat-ando3610.html
# Elstone Chesterfield Sofa https://www.wayfair.com/furniture/pdp/willa-arlo-interiors-elstone-chesterfield-sofa-wrlo7049.html
# Shullsburg Loveseat https://www.wayfair.com/furniture/pdp/gracie-oaks-shullsburg-loveseat-w000498808.html
# Marin Loveseat https://www.wayfair.com/furniture/pdp/mistana-marin-loveseat-w000112042.html
# Nyx Sofa https://www.wayfair.com/furniture/pdp/andover-mills-nyx-sofa-w001503424.html
# Suffield Serta Upholstery Sofa https://www.wayfair.com/furniture/pdp/three-posts-suffield-serta-upholstery-sofa-w001263140.html
# Bittle Sofa https://www.wayfair.com/furniture/pdp/wrought-studio-bittle-sofa-vrkg3659.html
# Boles Modular Sofa https://www.wayfair.com/furniture/pdp/trule-teen-boles-modular-sofa-w000507501.html
# Les Sofa https://www.wayfair.com/furniture/pdp/willa-arlo-interiors-les-sofa-wlro1170.html
# Cece Standard Loveseat https://www.wayfair.com/furniture/pdp/andover-mills-cece-standard-loveseat-w000614087.html
# Deschutes Modern Loveseat https://www.wayfair.com/furniture/pdp/andover-mills-deschutes-modern-loveseat-andv4712.html
# Lindstrom Chesterfield Sofa https://www.wayfair.com/furniture/pdp/darby-home-co-lindstrom-chesterfield-sofa-dbyh8201.html
# Celestia Loveseat https://www.wayfair.com/furniture/pdp/andover-mills-celestia-loveseat-w001503441.html
# Keltner Tufted Camelback Sofa https://www.wayfair.com/furniture/pdp/willa-arlo-interiors-keltner-tufted-camelback-sofa-wlro1148.html
# Bittle Modern Living Room Loveseat https://www.wayfair.com/furniture/pdp/wrought-studio-bittle-modern-living-room-loveseat-vrkg3662.html
# Cabrini Sofa https://www.wayfair.com/furniture/pdp/latitude-run-cabrini-sofa-lder7916.html
# Gorgonio Tufted Mid Century Loveseat https://www.wayfair.com/furniture/pdp/trent-austin-design-gorgonio-tufted-mid-century-loveseat-trnt3381.html
# Wythe Sofa https://www.wayfair.com/furniture/pdp/canora-grey-wythe-sofa-cagy1156.html
# Coyan Loveseat https://www.wayfair.com/furniture/pdp/mistana-coyan-loveseat-mtna1994.html
# Lester Loveseat https://www.wayfair.com/furniture/pdp/rosdorf-park-lester-loveseat-rosp8068.html
# Marin Standard Sofa https://www.wayfair.com/furniture/pdp/mistana-marin-standard-sofa-w000310537.html
# Elmore Loveseat https://www.wayfair.com/furniture/pdp/wrought-studio-elmore-loveseat-vrkg1227.html
# Marrs Sofa https://www.wayfair.com/furniture/pdp/house-of-hampton-marrs-sofa-w001480025.html
# Yara Settee https://www.wayfair.com/furniture/pdp/mercer41-yara-settee-w000064844.html
# Bilski Tufted Loveseat https://www.wayfair.com/furniture/pdp/langley-street-bilski-tufted-loveseat-lgly6668.html
# Martelli Sofa https://www.wayfair.com/furniture/pdp/mercury-row-martelli-sofa-w001340996.html
# Irenee Loveseat with Pillow https://www.wayfair.com/furniture/pdp/lark-manor-irenee-loveseat-with-pillow-lrkm4181.html
# Swoop Settee https://www.wayfair.com/furniture/pdp/brayden-studio-swoop-settee-brsd2141.html
# Anders Loveseat https://www.wayfair.com/furniture/pdp/ebern-designs-anders-loveseat-uspf1011.html
# Wild Modern Standard Settee https://www.wayfair.com/furniture/pdp/house-of-hampton-wild-modern-standard-settee-xjt10000.html
# Onancock Nailhead Trim Loveseat https://www.wayfair.com/furniture/pdp/brayden-studio-onancock-nailhead-trim-loveseat-w001342072.html
# Valencia Mid-Century Loveseat https://www.wayfair.com/furniture/pdp/wholesale-interiors-valencia-mid-century-loveseat-whi7867.html
# Elstone Chesterfield Loveseat https://www.wayfair.com/furniture/pdp/willa-arlo-interiors-elstone-chesterfield-loveseat-wrlo6946.html
# Kaia Armless Settee https://www.wayfair.com/furniture/pdp/ivy-bronx-kaia-armless-settee-ivyb8044.html
# Gaines Settee https://www.wayfair.com/furniture/pdp/world-menagerie-gaines-settee-wdmg4775.html
# Luciano Loveseat https://www.wayfair.com/furniture/pdp/george-oliver-luciano-loveseat-uspf9379.html
# Beallsville Sofa https://www.wayfair.com/furniture/pdp/darby-home-co-beallsville-sofa-drbc8702.html
# Arendtsville Settee https://www.wayfair.com/furniture/pdp/birch-lane-heritage-arendtsville-settee-bl23367.html
# Bigelow Sofa https://www.wayfair.com/furniture/pdp/fleur-de-lis-living-bigelow-sofa-fdlv1223.html
# Kingsport Reversible Sectional https://www.wayfair.com/furniture/pdp/red-barrel-studio-kingsport-reversible-sectional-rdbl4484.html
# Onancock Nailhead Trim Sofa https://www.wayfair.com/furniture/pdp/brayden-studio-onancock-nailhead-trim-sofa-w001342232.html
# Birdwatcher Settee https://www.wayfair.com/furniture/pdp/skyline-furniture-birdwatcher-settee-sky8729.html
# Boles Modular Love Seat https://www.wayfair.com/furniture/pdp/trule-teen-boles-modular-love-seat-w000291336.html
# Gibson Loveseat https://www.wayfair.com/furniture/pdp/mercer41-gibson-loveseat-w000815135.html
# Sunray Modern Loveseat https://www.wayfair.com/furniture/pdp/orren-ellis-sunray-modern-loveseat-w000229530.html
# Kadlec Leather Chesterfield Loveseat https://www.wayfair.com/furniture/pdp/alcott-hill-kadlec-leather-chesterfield-loveseat-tnfr1031.html
